# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for A in range(1000, 0, -1):
    flag = 0
    for x in range(0, 1000, 1):
        F = (((x&51) == 0) or (((x&41) == 0) <= ((x&A) == 0)))
        if F == 0:
            flag = 1
            break
    if flag == 0:
        print(A)
        break
# Out:
# 41

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for A in range(1000, 0, -1):
    flag = 0
    for x in range(0, 1000, 1):
        for y in range(0, 1000, 1):
            F = (((x<=9)<=(x*x<=A))and((y*y<=A)<=(y<=9))) 
            if F == 0:
                flag = 1
                break 
        if flag == 1:
            break
    if flag == 0:
        print(A)
        break
# Out:
# 99

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for a in range(1000, 0, -1):
    flag = 0 
    for x in range(1, 1000, 1):
        f = (a < 50) and ((not(x%a==0)) <= ((x%10==0) <= (not(x%12==0))))
        if f != 1:
            flag = 1
            break 
    if flag == 0:
        print(a)
        break
# Out:
# 30

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# ДЕЛ(n,m) -> n % m == 0
for A in range(1, 1000, 1):# (1<---, 1000, 1) A натуральное число
    f = 0
    for x in range(0, 16000, 1):
        if ((not(x % 100 == 0) and (x % 4 == 0)) or (x % 400 == 0) or not(x % A == 0)) == 0: # <-- #(т. е. принимает значение 1 при любом неотрицательном целом значении переменной х)
            f = 1
    if f == 0:
        print(A)
        break

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for A in range(0, 1000, 1):
    f = 0
    for x in range(0, 10000, 1):
        if (((x&52 != 0) and (x&48 == 0)) <= (not(x&A == 0))) == 0:
            f = 1
    if f == 0:
        print(A)
        break
