# %%
def f(a):
    print(a + 1)
# рекурсия - это вызов функции в самой себе, для нее нужно задать точку остановки, чтобы не делать её бесконечно 
def p(n):
    if n == 1:
        return 1
    else:
        return n + p(n-1)
# Out:
# 15

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n == 1:
        return 1
    if n == 2:
        return 1
    if n>2:
        return f(n-2)*(n-1)
print(f(8))
# Out:
# 105

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n == 0:
        return 0
    if n > 0 and n%2 == 0:
        return f(n//2)
    if n%2 == 1:
        return 1 + f(n-1)
c = 0
for n in range(1, 1001, 1):
    if f(n) == 3:
        c += 1
print(c)
# Out:
# 120

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n == 1:
        return 1
    if n > 1:
        return n * f(n-1)

print(2023 * 2022 * 2021) #print(2023 * 2022 * 2021 * f(2020)) // f(2020)

#print(f(2023) // f(2020)) слишком много считать
# Out:
# 8266912626

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n == 1:
        return 1
    if n % 2 == 1 and n > 1:
        return n + f(n - 2)
    if n % 2 == 0:
        return n * f(n - 1)
print(f(40))
# Out:
# 16000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n == 1:
        return 1
    if n >= 2:
        return f(n -1) - g(n - 1)
def g(n):
    if n == 1:
        return 1
    if n >= 2:
        return f(n - 1) + g(n - 1)
print(f(5)/g(5))
# #При каком минимальном значении n величина F(n)/G(n) принимает значение 5
# for n in range(1,10000,1):
#     if f(n)/g(n) == 5:
#         print(n)
#         break

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n >= 2025:
        return n
    if n < 2025:
        return n * 2 + f(n + 2)
print(f(82) - f(81))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n < 3:
        return n
    if n >= 3:
        return (n - 1) * f(n - 2)
print((f(2024)-f(2022))/f(2020))

# f(2024) - f(2022) = 2023*f(2022) - f(2022) = f(2022) * (2023 - 1) = f(2022) * 2022 = 2021 * f(2020) * 2022

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n == 0:
        return 0
    if n > 0 and n % 2 == 0:
        return f(n//2) 
    if n % 2 == 1:
        return 1 + f(n - 1)
c = 0
for n in range(1, 501, 1):
    if f(n) == 8:
        c += 1
print(c)
