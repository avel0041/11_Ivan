# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 5402

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 720

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 3806

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for x in range(2300, -1, -1):
    a1 = 7**350 + 7**150 - x
    s = ''
    b = a1
    while b != 0:
        s = s + str(b%7)
        b = b//7
    s = s[::-1]
    if s.count('0') == 200:
        print(x)
        break
# Out:
# 2001

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 19

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 82619
# 115709 78

# %% [markdown]
# ![image.png](attachment:image.png)
