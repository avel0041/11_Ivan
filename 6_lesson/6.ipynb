# %% [markdown]
# Дана некоторая строка. Найди индекс первого нуля в строке

# %%
s = '12348763410174138013746410'

for i in range(0, len(s)): 
    if s[i] == '0':
        print(i)
        break #прервать цикл после первого верного if
# Out:
# 10

# %% [markdown]
# Проверь число пользователя на простоту

# %%
a = int(input())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
